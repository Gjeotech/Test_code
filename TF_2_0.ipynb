# %% [markdown]
# <a href="https://colab.research.google.com/github/Gjeotech/Test_code/blob/main/TF_2_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Public link

# %%
! wget = https://github.com/datasciencedojo/datasets/blob/master/titanic.csv
# Out:
# --2023-11-13 08:13:35--  http://=/
# Resolving = (=)... failed: Name or service not known.
# wget: unable to resolve host address ‘=’
# --2023-11-13 08:13:35--  https://github.com/datasciencedojo/datasets/blob/master/titanic.csv
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 88090 (86K) [text/plain]
# Saving to: ‘titanic.csv’
#
# titanic.csv         100%[===================>]  86.03K   475KB/s    in 0.2s
#
# 2023-11-13 08:13:36 (475 KB/s) - ‘titanic.csv’ saved [88090/88090]
#
# FINISHED --2023-11-13 08:13:36--
# Total wall clock time: 0.6s
# Downloaded: 1 files, 86K in 0.2s (475 KB/s)

# %%
# !ls
# Out:
# sample_data  titanic.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('titanic.csv',sep='\t')

# %%
# data

# %%
import numpy as np

# %%
data2 = pd.read_csv('SuperstoreSalesDataset.csv')

# %%
data2.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %% [markdown]
# ```
# # This is formatted as code
#
# for i in range(29):
#     print(i)
# ```

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %% [markdown]
# $ ax^2 +bx + c = 0$

# %% [markdown]
# $x1 = \frac{a}{b}$

# %% [markdown]
# $$Equ1 = \frac{-b + \sqrt(b^2 -4ac)}{2a}$$

# %% [markdown]
# [Google search Engine
# \\\\](https://google.com)

# %% [markdown]
# ## Analysis

# %%
data2.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
Odate = data2['Order Date'];
sales = data2['Sales'];

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SalesRange = data2[data2['Sales'] >= 3000]

# %%
SalesRange
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 27        28  US-2016-150630  17/09/2016  21/09/2016  Standard Class
# 165      166  CA-2015-139892  08/09/2015  12/09/2015  Standard Class
# 251      252  CA-2017-145625  11/09/2017  17/09/2017  Standard Class
# 262      263  US-2015-106992  19/09/2015  21/09/2015    Second Class
# 318      319  CA-2015-164973  04/11/2015  09/11/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9425    9426  CA-2015-116246  12/09/2015  17/09/2015    Second Class
# 9639    9640  CA-2016-116638  28/01/2016  31/01/2016    Second Class
# 9649    9650  CA-2017-107104  26/11/2017  30/11/2017  Standard Class
# 9660    9661  CA-2017-160717  06/06/2017  11/06/2017  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID        Customer Name      Segment        Country  \
# 27      TB-21520      Tracy Blumstein     Consumer  United States
# ...

# %%
SalesRange.shape
# Out:
# (62, 18)

# %%
SalesRange.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
  ax = plt.figure(figsize=(30,10))
  plt.title("Sales Above 3000", fontsize=18)
  plt.bar(SalesRange['Order Date'],SalesRange['Sales'])
  plt.xticks(SalesRange['Order Date'], rotation=80)
  plt.show()

# %%
sns.relplot(x=SalesRange['Order Date'], y=SalesRange['Sales'])
